# %%
# %pip install emukit
from emukit.core import ContinuousParameter, ParameterSpace
import matplotlib as plt
from GPy.models import GPRegression
from emukit.model_wrappers import GPyModelWrapper

from emukit.sensitivity.monte_carlo import MonteCarloSensitivity
# Out:
# Requirement already satisfied: emukit in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (0.4.10)
# Requirement already satisfied: setuptools>=40.8.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from emukit) (41.2.0)
# Requirement already satisfied: numpy>=1.14.5 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from emukit) (1.24.3)
# Requirement already satisfied: GPy[plotting]>=1.10.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from emukit) (1.10.0)
# Requirement already satisfied: emcee>=2.2.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from emukit) (3.1.4)
# Requirement already satisfied: scipy>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from emukit) (1.10.1)
# Requirement already satisfied: six in /Users/israelmason-williams/Library/Python/3.8/lib/python/site-packages (from GPy[plotting]>=1.10.0->emukit) (1.14.0)
# Requirement already satisfied: paramz>=0.9.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from GPy[plotting]>=1.10.0->emukit) (0.9.6)
# Requirement already satisfied: cython>=0.29 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from GPy[plotting]>=1.10.0->emukit) (3.0.8)
# Requirement already satisfied: matplotlib>=3.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from GPy[plotting]>=1.10.0->emukit) (3.7.2)
# Requirement already satisfied: plotly>=1.8.6 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from GPy[plotting]>=1.10.0->emukit) (5.15.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from matplotlib>=3.0->GPy[plotting]>=1.10.0->emukit) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from matplotlib>=3.0->GPy[plotting]>=1.10.0->emukit) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from matplotlib>=3.0->GPy[plotting]>=1.10.0->emukit) (4.41.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from matplotlib>=3.0->GPy[plotting]>=1.10.0->emukit) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from matplotlib>=3.0->GPy[plotting]>=1.10.0->emukit) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from matplotlib>=3.0->GPy[plotting]>=1.10.0->emukit) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from matplotlib>=3.0->GPy[plotting]>=1.10.0->emukit) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from matplotlib>=3.0->GPy[plotting]>=1.10.0->emukit) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from matplotlib>=3.0->GPy[plotting]>=1.10.0->emukit) (6.0.0)
# Requirement already satisfied: decorator>=4.0.10 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from paramz>=0.9.0->GPy[plotting]>=1.10.0->emukit) (4.4.2)
# Requirement already satisfied: tenacity>=6.2.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from plotly>=1.8.6->GPy[plotting]>=1.10.0->emukit) (8.2.2)
# Requirement already satisfied: zipp>=3.1.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.0->GPy[plotting]>=1.10.0->emukit) (3.16.2)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import gc
import numpy as np
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import matplotlib.pyplot as plt

# %% [markdown]
# # Load dataset

# %%
df = pd.read_csv("./CASP15_global_error.csv")

# %%
df
# Out:
#       AL0_P  TM-score  TM-align  AL4_P    QCS  Z-score  Handed.     SS   DFM  \
# 0     77.78     0.794     0.797  88.89  87.09     7.43     0.91  0.463  0.17
# 1     36.47     0.410     0.444  41.76  53.52     2.81     0.91  0.520  0.37
# 2     72.17     0.888     0.893  87.39  97.86    12.90     0.94  0.650  0.09
# 3     95.50     0.921     0.924  98.20  97.10     8.25     0.95  0.678  0.04
# 4     57.27     0.571     0.569  64.55  67.85     3.86     0.92  0.462  0.22
# ...     ...       ...       ...    ...    ...      ...      ...    ...   ...
# 3999  95.50     0.929     0.932  98.20  97.33     8.25     0.95  0.694  0.04
# 4000  95.93     0.972     0.972  96.83  99.00    10.91     0.97  0.780  0.05
# 4001  95.50     0.943     0.946  98.20  97.77     8.25     0.96  0.698  0.04
# 4002   0.00     0.388     0.405   0.00  26.25     0.84     0.80  0.204  0.32
# 4003  88.33     0.733     0.733  98.33  79.79     5.93     0.90  0.429  0.06
#
#       GDT_TS
# 0      76.92
# 1      38.38
# 2      70.54
# 3      91.89
# 4      55.45
# ...      ...
# 3999   92.57
# 4000   96.49
# 4001   95.05
# 4002   48.33
# 4003   82.08
#
# [4004 rows x 10 columns]

# %%
stats = df.describe()
stats
# Out:
#              AL0_P     TM-score     TM-align        AL4_P          QCS  \
# count  4004.000000  4004.000000  4004.000000  4004.000000  4004.000000
# mean     70.993679     0.739573     0.745745    78.432403    82.152048
# std      26.351493     0.221429     0.217037    25.011285    21.180742
# min       0.000000     0.121000     0.178000     0.000000     8.790000
# 25%      57.270000     0.578000     0.578000    65.270000    73.860000
# 50%      75.650000     0.825000     0.830000    89.740000    91.480000
# 75%      95.500000     0.930000     0.932000    96.830000    97.660000
# max      99.400000     0.983000     0.983000   100.000000    99.230000
#
#            Z-score      Handed.           SS          DFM       GDT_TS
# count  4004.000000  4004.000000  4004.000000  4004.000000  4004.000000
# mean      6.980502     0.902587     0.564950     0.237545    72.530145
# std       3.657681     0.094822     0.149368     0.333540    21.737269
# min      -2.350000     0.520000     0.054000     0.010000    10.910000
# 25%       4.080000     0.900000     0.473000     0.050000    58.550000
# 50%       8.060000     0.940000     0.562000     0.080000    78.480000
# 75%       9.730000     0.960000     0.686000     0.250000    91.670000
# max      13.900000     0.980000     0.794000     1.800000    97.920000

# %%
seed_values = [45,46,47,48,49,50]

# %%
def scale_data(option,df):
  if option ==1:
    arr_scaled = df.drop('GDT_TS', axis=1).to_numpy()
    arr_scaled
  elif option ==2:
    scaler = MinMaxScaler()
    scaler.fit(df.drop('GDT_TS', axis=1))
    arr_scaled = scaler.transform(df.drop('GDT_TS', axis=1))
    arr_scaled
  else:
    scaler = StandardScaler()
    scaler.fit(df.drop('GDT_TS', axis=1))
    arr_scaled = scaler.transform(df.drop('GDT_TS', axis=1))
    arr_scaled

  df_scaled = pd.DataFrame(data=arr_scaled, columns=df.drop('GDT_TS', axis=1).columns)
  stats = df_scaled.describe()
  return arr_scaled,stats

# %%
def sensitivity_analysis(df,arr_scaled,seed_values,stats):
  main_effects_list = []
  total_effects_list = []

  for seed_value in seed_values:
      np.random.seed(seed_value)

      # space = ParameterSpace([ContinuousParameter('x1', 2000, 50000),
      #                         ContinuousParameter('x2', 400, 16000)])

      space = ParameterSpace([ContinuousParameter(feat, stats[feat].loc['min'], stats[feat].loc['max']) for feat in stats.columns])

      Y = df['GDT_TS'].to_numpy().reshape(-1,1)
      #Y.shape
      X = arr_scaled
      #X.shape

      model_gpy = GPRegression(X,Y)
      model_emukit = GPyModelWrapper(model_gpy)
      model_emukit.optimize()

      senstivity = MonteCarloSensitivity(model = model_emukit, input_domain = space)
      main_effects, total_effects, _ = senstivity.compute_effects(num_monte_carlo_points = 10000)
      #main_effects_minmaxscaler, total_effects_minmaxscaler, _ = senstivity.compute_effects(num_monte_carlo_points = 10000)
      #main_effects_stdscaler, total_effects_stdscaler, _ = senstivity.compute_effects(num_monte_carlo_points = 10000)

      print(f"Seed {seed_value}, main effects:", main_effects)
      print(f"Seed {seed_value}, total effects:", total_effects)

      main_effects_list.append(main_effects)
      total_effects_list.append(total_effects)
      del(model_gpy)
      del(model_emukit)
      del(senstivity)
      gc.collect()
  return main_effects_list,total_effects_list

# %%
def effects_list_to_df(effects_list):
    feats = effects_list[0].keys()

    feat_values = []
    for dic in effects_list:
        feat_values.append([val[0] for feat, val in dic.items()])

    feat_values = np.array(feat_values)
    df = pd.DataFrame(data=feat_values, columns=feats)

    return df

# %% [markdown]
# #Without Scaling

# %%
arr_scaled,stats = scale_data(1,df)
main_effects_list,total_effects_list = sensitivity_analysis(df,arr_scaled,seed_values,stats)
df_main_effects = effects_list_to_df(main_effects_list)
df_main_effects.to_csv('main_effects_ws.csv', index=False)

df_total_effects = effects_list_to_df(total_effects_list)
df_total_effects.to_csv('total_effects_ws.csv', index=False)
# Out:
# Seed 45, main effects: {'AL0_P': array([0.00186046]), 'TM-score': array([0.00387677]), 'TM-align': array([0.00573047]), 'AL4_P': array([0.11341231]), 'QCS': array([0.0719706]), 'Z-score': array([0.00092705]), 'Handed.': array([0.00471145]), 'SS': array([0.00461757]), 'DFM': array([0.00716536])}
# Seed 45, total effects: {'AL0_P': array([0.662088]), 'TM-score': array([0.00500053]), 'TM-align': array([0.00018816]), 'AL4_P': array([0.77595268]), 'QCS': array([0.66169462]), 'Z-score': array([0.21926821]), 'Handed.': array([-0.00224272]), 'SS': array([-0.00125954]), 'DFM': array([0.00824545])}
# Seed 46, main effects: {'AL0_P': array([0.02250263]), 'TM-score': array([-0.00922784]), 'TM-align': array([-0.00825169]), 'AL4_P': array([0.09070306]), 'QCS': array([0.05249323]), 'Z-score': array([-0.00738586]), 'Handed.': array([-0.00948947]), 'SS': array([-0.01022715]), 'DFM': array([-0.00694665])}
# Seed 46, total effects: {'AL0_P': array([0.72654979]), 'TM-score': array([0.0036304]), 'TM-align': array([0.00317143]), 'AL4_P': array([0.77986375]), 'QCS': array([0.70645786]), 'Z-score': array([0.21698596]), 'Handed.': array([-0.00195892]), 'SS': array([-0.00148325]), 'DFM': array([0.00361905])}
# Seed 47, main effects: {'AL0_P': array([0.01247995]), 'TM-score': array([-0.00234774]), 'TM-align': array([0.00053183]), 'AL4_P': array([0.09409074]), 'QCS': array([0.05721346]), 'Z-score': array([-0.01053764]), 'Handed.': array([-0.00142566]), 'SS': array([-0.00181344]), 'DFM': array([-0.00142852])}
# Seed 47, total effects: {'AL0_P': array([0.71944802]), 'TM-score': array([-0.00023358]), 'TM-align': array([-0.00292581]), 'AL4_P': array([0.77161566]), 'QCS': array([0.69857637]), 'Z-score': array([0.21165702]), 'Handed.': array([-0.00724715]), 'SS': array([-0.00651889]), 'DFM': array([0.00231833])}
# Seed 48, main effects: {'AL0_P': array([-0.01029091]), 'TM-score': array([0.00452326]), 'TM-align': array([0.00225744]), 'AL4_P': array([0.0982028]), 'QCS': array([0.06166811]), 'Z-score': array([-0.00463244]), 'Handed.': array([0.00206011]), 'SS': array([0.0015828]), 'DFM': array([0.00528315])}
# Seed 48, total effects: {'AL0_P': array([0.7015048]), 'TM-score': array([0.02674644]), 'TM-align': array([0.02501992]), 'AL4_P': array([0.74628596]), 'QCS': array([0.6366326]), 'Z-score': array([0.24375057]), 'Handed.': array([0.02018732]), 'SS': array([0.02154662]), 'DFM': array([0.0285983])}
# Seed 49, main effects: {'AL0_P': array([-0.00438281]), 'TM-score': array([0.00781792]), 'TM-align': array([0.00731029]), 'AL4_P': array([0.10846755]), 'QCS': array([0.06507534]), 'Z-score': array([0.00025847]), 'Handed.': array([0.0070751]), 'SS': array([0.00691789]), 'DFM': array([0.00685117])}
# Seed 49, total effects: {'AL0_P': array([0.67904528]), 'TM-score': array([-0.02069371]), 'TM-align': array([-0.02385696]), 'AL4_P': array([0.77212658]), 'QCS': array([0.68423276]), 'Z-score': array([0.20351134]), 'Handed.': array([-0.02912238]), 'SS': array([-0.02766547]), 'DFM': array([-0.01744284])}
# Seed 50, main effects: {'AL0_P': array([-0.00310895]), 'TM-score': array([0.0033646]), 'TM-align': array([0.00422377]), 'AL4_P': array([0.11140359]), 'QCS': array([0.06620321]), 'Z-score': array([-0.00196509]), 'Handed.': array([0.00218744]), 'SS': array([0.0011063]), 'DFM': array([0.00226944])}
# Seed 50, total effects: {'AL0_P': array([0.72062563]), 'TM-score': array([0.0380466]), 'TM-align': array([0.03663072]), 'AL4_P': array([0.80453709]), 'QCS': array([0.71448422]), 'Z-score': array([0.25273957]), 'Handed.': array([0.03160329]), 'SS': array([0.03259031]), 'DFM': array([0.03793612])}

# %% [markdown]
# # Min Max

# %%
arr_scaled,stats = scale_data(2,df)
main_effects_list,total_effects_list = sensitivity_analysis(df,arr_scaled,seed_values,stats)
df_main_effects = effects_list_to_df(main_effects_list)
df_main_effects.to_csv('main_effects_mm.csv', index=False)

df_total_effects = effects_list_to_df(total_effects_list)
df_total_effects.to_csv('total_effects_mm.csv', index=False)
# Out:
# Seed 45, main effects: {'AL0_P': array([0.02064432]), 'TM-score': array([0.03934614]), 'TM-align': array([0.03308379]), 'AL4_P': array([0.05140924]), 'QCS': array([0.00843242]), 'Z-score': array([0.0380231]), 'Handed.': array([0.0074656]), 'SS': array([0.00792133]), 'DFM': array([0.03065728])}
# Seed 45, total effects: {'AL0_P': array([0.30711672]), 'TM-score': array([0.36486613]), 'TM-align': array([0.33882286]), 'AL4_P': array([0.35095541]), 'QCS': array([0.27340324]), 'Z-score': array([0.324429]), 'Handed.': array([0.23507973]), 'SS': array([0.21660541]), 'DFM': array([0.31320994])}
# Seed 46, main effects: {'AL0_P': array([0.02949528]), 'TM-score': array([0.04933283]), 'TM-align': array([0.02402342]), 'AL4_P': array([0.03909337]), 'QCS': array([0.01228141]), 'Z-score': array([0.03699857]), 'Handed.': array([0.01046892]), 'SS': array([0.0209333]), 'DFM': array([0.04054574])}
# Seed 46, total effects: {'AL0_P': array([0.37255697]), 'TM-score': array([0.43304697]), 'TM-align': array([0.4303613]), 'AL4_P': array([0.43245136]), 'QCS': array([0.3364132]), 'Z-score': array([0.36748267]), 'Handed.': array([0.32920584]), 'SS': array([0.29219576]), 'DFM': array([0.40322017])}
# Seed 47, main effects: {'AL0_P': array([0.02947072]), 'TM-score': array([0.07452058]), 'TM-align': array([0.04011919]), 'AL4_P': array([0.05212963]), 'QCS': array([0.04555401]), 'Z-score': array([0.06257866]), 'Handed.': array([0.02685904]), 'SS': array([0.04523769]), 'DFM': array([0.05686804])}
# Seed 47, total effects: {'AL0_P': array([0.2395122]), 'TM-score': array([0.27993312]), 'TM-align': array([0.23954002]), 'AL4_P': array([0.27986407]), 'QCS': array([0.20092886]), 'Z-score': array([0.23524776]), 'Handed.': array([0.18068064]), 'SS': array([0.13686173]), 'DFM': array([0.27676231])}
# Seed 48, main effects: {'AL0_P': array([0.01432314]), 'TM-score': array([0.05880828]), 'TM-align': array([0.04103945]), 'AL4_P': array([0.02600735]), 'QCS': array([0.00967024]), 'Z-score': array([0.05130844]), 'Handed.': array([0.01771684]), 'SS': array([0.01593735]), 'DFM': array([0.04033122])}
# Seed 48, total effects: {'AL0_P': array([0.32795034]), 'TM-score': array([0.35503847]), 'TM-align': array([0.34075134]), 'AL4_P': array([0.36274934]), 'QCS': array([0.26982178]), 'Z-score': array([0.31072605]), 'Handed.': array([0.27807994]), 'SS': array([0.23753251]), 'DFM': array([0.29885414])}
# Seed 49, main effects: {'AL0_P': array([0.0238075]), 'TM-score': array([0.04870482]), 'TM-align': array([0.04449298]), 'AL4_P': array([0.06642986]), 'QCS': array([0.01650348]), 'Z-score': array([0.05180064]), 'Handed.': array([0.02415821]), 'SS': array([0.02091729]), 'DFM': array([0.03487867])}
# Seed 49, total effects: {'AL0_P': array([0.16463644]), 'TM-score': array([0.24509344]), 'TM-align': array([0.23776918]), 'AL4_P': array([0.21765417]), 'QCS': array([0.15288376]), 'Z-score': array([0.13611519]), 'Handed.': array([0.07039133]), 'SS': array([0.02460024]), 'DFM': array([0.20909866])}
# Seed 50, main effects: {'AL0_P': array([0.02207529]), 'TM-score': array([0.05650333]), 'TM-align': array([0.0318297]), 'AL4_P': array([0.03000516]), 'QCS': array([0.02042103]), 'Z-score': array([0.04322515]), 'Handed.': array([0.00761799]), 'SS': array([0.01829337]), 'DFM': array([0.0561218])}
# Seed 50, total effects: {'AL0_P': array([0.32526102]), 'TM-score': array([0.36356617]), 'TM-align': array([0.34318767]), 'AL4_P': array([0.36931766]), 'QCS': array([0.28845789]), 'Z-score': array([0.32442695]), 'Handed.': array([0.26672938]), 'SS': array([0.20204897]), 'DFM': array([0.31192012])}

# %% [markdown]
# # Standard Scalling

# %%
arr_scaled,stats = scale_data(3,df)
main_effects_list,total_effects_list = sensitivity_analysis(df,arr_scaled,seed_values,stats)
df_main_effects = effects_list_to_df(main_effects_list)
df_main_effects.to_csv('main_effects_ss.csv', index=False)

df_total_effects = effects_list_to_df(total_effects_list)
df_total_effects.to_csv('total_effects_ss.csv', index=False)
# Out:
# Seed 45, main effects: {'AL0_P': array([0.02064432]), 'TM-score': array([0.03934614]), 'TM-align': array([0.03308379]), 'AL4_P': array([0.05140924]), 'QCS': array([0.00843242]), 'Z-score': array([0.0380231]), 'Handed.': array([0.0074656]), 'SS': array([0.00792133]), 'DFM': array([0.03065728])}
# Seed 45, total effects: {'AL0_P': array([0.30711672]), 'TM-score': array([0.36486613]), 'TM-align': array([0.33882286]), 'AL4_P': array([0.35095541]), 'QCS': array([0.27340324]), 'Z-score': array([0.324429]), 'Handed.': array([0.23507973]), 'SS': array([0.21660541]), 'DFM': array([0.31320994])}
# Seed 46, main effects: {'AL0_P': array([0.02949528]), 'TM-score': array([0.04933283]), 'TM-align': array([0.02402342]), 'AL4_P': array([0.03909337]), 'QCS': array([0.01228141]), 'Z-score': array([0.03699857]), 'Handed.': array([0.01046892]), 'SS': array([0.0209333]), 'DFM': array([0.04054574])}
# Seed 46, total effects: {'AL0_P': array([0.37255697]), 'TM-score': array([0.43304697]), 'TM-align': array([0.4303613]), 'AL4_P': array([0.43245136]), 'QCS': array([0.3364132]), 'Z-score': array([0.36748267]), 'Handed.': array([0.32920584]), 'SS': array([0.29219576]), 'DFM': array([0.40322017])}
# Seed 47, main effects: {'AL0_P': array([0.02947072]), 'TM-score': array([0.07452058]), 'TM-align': array([0.04011919]), 'AL4_P': array([0.05212963]), 'QCS': array([0.04555401]), 'Z-score': array([0.06257866]), 'Handed.': array([0.02685904]), 'SS': array([0.04523769]), 'DFM': array([0.05686804])}
# Seed 47, total effects: {'AL0_P': array([0.2395122]), 'TM-score': array([0.27993312]), 'TM-align': array([0.23954002]), 'AL4_P': array([0.27986407]), 'QCS': array([0.20092886]), 'Z-score': array([0.23524776]), 'Handed.': array([0.18068064]), 'SS': array([0.13686173]), 'DFM': array([0.27676231])}
# Seed 48, main effects: {'AL0_P': array([0.01432314]), 'TM-score': array([0.05880828]), 'TM-align': array([0.04103945]), 'AL4_P': array([0.02600735]), 'QCS': array([0.00967024]), 'Z-score': array([0.05130844]), 'Handed.': array([0.01771684]), 'SS': array([0.01593735]), 'DFM': array([0.04033122])}
# Seed 48, total effects: {'AL0_P': array([0.32795034]), 'TM-score': array([0.35503847]), 'TM-align': array([0.34075134]), 'AL4_P': array([0.36274934]), 'QCS': array([0.26982178]), 'Z-score': array([0.31072605]), 'Handed.': array([0.27807994]), 'SS': array([0.23753251]), 'DFM': array([0.29885414])}
# Seed 49, main effects: {'AL0_P': array([0.0238075]), 'TM-score': array([0.04870482]), 'TM-align': array([0.04449298]), 'AL4_P': array([0.06642986]), 'QCS': array([0.01650348]), 'Z-score': array([0.05180064]), 'Handed.': array([0.02415821]), 'SS': array([0.02091729]), 'DFM': array([0.03487867])}
# Seed 49, total effects: {'AL0_P': array([0.16463644]), 'TM-score': array([0.24509344]), 'TM-align': array([0.23776918]), 'AL4_P': array([0.21765417]), 'QCS': array([0.15288376]), 'Z-score': array([0.13611519]), 'Handed.': array([0.07039133]), 'SS': array([0.02460024]), 'DFM': array([0.20909866])}
# Seed 50, main effects: {'AL0_P': array([0.02207529]), 'TM-score': array([0.05650333]), 'TM-align': array([0.0318297]), 'AL4_P': array([0.03000516]), 'QCS': array([0.02042103]), 'Z-score': array([0.04322515]), 'Handed.': array([0.00761799]), 'SS': array([0.01829337]), 'DFM': array([0.0561218])}
# Seed 50, total effects: {'AL0_P': array([0.32526102]), 'TM-score': array([0.36356617]), 'TM-align': array([0.34318767]), 'AL4_P': array([0.36931766]), 'QCS': array([0.28845789]), 'Z-score': array([0.32442695]), 'Handed.': array([0.26672938]), 'SS': array([0.20204897]), 'DFM': array([0.31192012])}

# %% [markdown]
# # Plotting data

# %% [markdown]
# Get dataframe of collumn Average

# %%
def average_std(df):
  average_values = df.mean()
  average_df = pd.DataFrame(average_values)
  average_df = average_df.T
  average_df.columns = df.columns

  std_dev_values = df.std()
  std_dev_df = pd.DataFrame(std_dev_values)
  std_dev_df = std_dev_df.T
  std_dev_df.columns = df.columns
  std_dev_df

  return average_df,std_dev_df

# %%
def plot_mean_std(average_df,std_dev_df,title,path):

    fig, ax = plt.subplots(figsize=(10, 5))
    ax.bar(average_df.columns, average_df.iloc[0], yerr=std_dev_df.iloc[0], capsize=5, label='Values with Std Dev')
    # Adding labels and title
    ax.set_xlabel('Parameters')
    ax.set_ylabel('Values')
    ax.set_title(title)

    # Show the plot
    plt.show()
    plt.savefig(path, format='pdf', bbox_inches='tight')

# %% [markdown]
# # Plotting No Scalling

# %%
main_effects = pd.read_csv("./main_effects.csv")
main_effects_average_df,main_effects_std_dev_df = average_std(main_effects)

main_effects_ss = pd.read_csv("./main_effects_stdscaler.csv")
main_effects_ss_average_df,main_effects_ss_std_dev_df = average_std(main_effects_ss)

main_effects_mm = pd.read_csv("./main_effects_minmaxscaler.csv")
main_effects_mm_average_df,main_effects_mm_std_dev_df = average_std(main_effects_mm)


fig, ax = plt.subplots(figsize=(6, 6))


bar_width = 0.15
bar_positions = np.arange(len(main_effects_average_df.columns))
ax.bar(bar_positions - bar_width, main_effects_average_df.iloc[0], width=bar_width, yerr=main_effects_std_dev_df.iloc[0], capsize=2, label='No Scaler')
ax.bar(bar_positions, main_effects_ss_average_df.iloc[0], width=bar_width, yerr=main_effects_ss_std_dev_df.iloc[0], capsize=2, label='Standard Scaler')
ax.bar(bar_positions + bar_width, main_effects_mm_average_df.iloc[0], width=bar_width, yerr=main_effects_mm_std_dev_df.iloc[0], capsize=2, label='MinMax Scaler')

ax.set_xlabel('Features',fontsize=14)
ax.set_ylabel('Main Effects Values',fontsize=14)

ax.set_xticks(bar_positions)
ax.set_xticklabels(main_effects_average_df.columns,fontsize=12)
plt.xticks(rotation = 90)
ax.legend()

plt.savefig('main_effects.pdf', format='pdf', bbox_inches='tight')

plt.show()

# %%
total_effects = pd.read_csv("./total_effects.csv")
total_effects_average_df,total_effects_std_dev_df = average_std(total_effects)

total_effects_ss = pd.read_csv("./total_effects_stdscaler.csv")
total_effects_ss_average_df,total_effects_ss_std_dev_df = average_std(total_effects_ss)

total_effects_mm = pd.read_csv("./total_effects_minmaxscaler.csv")
total_effects_mm_average_df,total_effects_mm_std_dev_df = average_std(total_effects_mm)


fig, ax = plt.subplots(figsize=(6, 6))


bar_width = 0.2
bar_positions = np.arange(len(main_effects_average_df.columns))
ax.bar(bar_positions - bar_width, total_effects_average_df.iloc[0], width=bar_width, yerr=total_effects_std_dev_df.iloc[0], capsize=2, label='No Scaler')
ax.bar(bar_positions, total_effects_ss_average_df.iloc[0], width=bar_width, yerr=total_effects_ss_std_dev_df.iloc[0], capsize=2, label='Standard Scaler')
ax.bar(bar_positions + bar_width, total_effects_mm_average_df.iloc[0], width=bar_width, yerr=mtotal_effects_mm_std_dev_df.iloc[0], capsize=2, label='MinMax Scaler')

ax.set_xlabel('Features',fontsize=14)
ax.set_ylabel('Values',fontsize=14)

ax.set_xticks(bar_positions)
ax.set_xticklabels(main_effects_average_df.columns,fontsize=12)
ax.legend()
plt.xticks(rotation = 90)
plt.savefig('Total_effects.pdf', format='pdf', bbox_inches='tight')

plt.show()
